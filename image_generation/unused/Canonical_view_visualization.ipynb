# %%
import PIL
from PIL import Image
from matplotlib import pyplot as plt

# %%
#path = "../output/views/rectangle_cylinder_011_gray_rubber_med/"
path = "../output/views/cube_011_gray_rubber_med/"
prefix = "1"

# %%
img = Image.open(path + prefix + "camera1.png")
plt.imshow(img)

# %%
fig, ax = plt.subplots(3,2)
fig.set_size_inches(15, 15)
img0 = Image.open(path+prefix+"camera1.png")
ax[0,0].imshow(img0)
img1 = Image.open(path+prefix+"camera2.png")
ax[0,1].imshow(img1)
img2 = Image.open(path+prefix+"camera3.png")
ax[1,0].imshow(img2)
img3 = Image.open(path+prefix+"camera4.png")
ax[1,1].imshow(img3)
img4 = Image.open(path+prefix+"camera_ori.png")
ax[2,0].imshow(img4)
img5 = Image.open(path+prefix+"camera_top.png")
ax[2,1].imshow(img5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-5e6e3975770f> in <module>
#       9 img3 = Image.open(path+prefix+"camera4.png")
#      10 ax[1,1].imshow(img3)
# ---> 11 img4 = Image.open(path+prefix+"camera_ori.png")
#      12 ax[2,0].imshow(img4)
#      13 img5 = Image.open(path+prefix+"camera_top.png")
#
# ~/anaconda3/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/views/cube_011_gray_rubber_med/1camera_ori.png'

# %%
top = 75
left = 125
bottom = 150
right = 200
crop_img0 = img0.crop((left, top, right, bottom))
crop_img1 = img1.crop((left, top, right, bottom))
crop_img2 = img2.crop((left, top, right, bottom))
crop_img3 = img3.crop((left, top, right, bottom))
crop_img4 = img4.crop((left, top, right, bottom))
crop_img5 = img5.crop((left, top, right, bottom))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-aa1664283d57> in <module>
#       7 crop_img2 = img2.crop((left, top, right, bottom))
#       8 crop_img3 = img3.crop((left, top, right, bottom))
# ----> 9 crop_img4 = img4.crop((left, top, right, bottom))
#      10 crop_img5 = img5.crop((left, top, right, bottom))
#
# NameError: name 'img4' is not defined

# %%
fig, ax = plt.subplots(3,2)
fig.set_size_inches(15, 15)
ax[0,0].imshow(crop_img0)
ax[0,1].imshow(crop_img1)
ax[1,0].imshow(crop_img2)
ax[1,1].imshow(crop_img3)
ax[2,0].imshow(crop_img4)
ax[2,1].imshow(crop_img5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-2a7af84ebff5> in <module>
#       5 ax[1,0].imshow(crop_img2)
#       6 ax[1,1].imshow(crop_img3)
# ----> 7 ax[2,0].imshow(crop_img4)
#       8 ax[2,1].imshow(crop_img5)
#
# NameError: name 'crop_img4' is not defined

# %%
top = 50
left = 100
bottom = 178
right = 228
crop_img0 = img0.crop((left, top, right, bottom))
crop_img1 = img1.crop((left, top, right, bottom))
crop_img2 = img2.crop((left, top, right, bottom))
crop_img3 = img3.crop((left, top, right, bottom))
crop_img4 = img4.crop((left, top, right, bottom))
crop_img5 = img5.crop((left, top, right, bottom))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b7b5d92c5848> in <module>
#       7 crop_img2 = img2.crop((left, top, right, bottom))
#       8 crop_img3 = img3.crop((left, top, right, bottom))
# ----> 9 crop_img4 = img4.crop((left, top, right, bottom))
#      10 crop_img5 = img5.crop((left, top, right, bottom))
#
# NameError: name 'img4' is not defined

# %%
fig, ax = plt.subplots(3,2)
fig.set_size_inches(15, 15)
ax[0,0].imshow(crop_img0)
ax[0,1].imshow(crop_img1)
ax[1,0].imshow(crop_img2)
ax[1,1].imshow(crop_img3)
ax[2,0].imshow(crop_img4)
ax[2,1].imshow(crop_img5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2a7af84ebff5> in <module>
#       5 ax[1,0].imshow(crop_img2)
#       6 ax[1,1].imshow(crop_img3)
# ----> 7 ax[2,0].imshow(crop_img4)
#       8 ax[2,1].imshow(crop_img5)
#
# NameError: name 'crop_img4' is not defined
